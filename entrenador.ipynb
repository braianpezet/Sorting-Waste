# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = 'datasets/dataset 3/paper'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    validation_split=0.2 #20% para pruebas
)

#Generadores para sets de entrenamiento y pruebas
data_gen_entrenamiento = datagen.flow_from_directory('datasets/dataset 3', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('datasets/dataset 3', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 12451 images belonging to 5 classes.
# Found 3110 images belonging to 5 classes.

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

mobilenetv2.trainable = False

# %%
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Entrenar el modelo
EPOCAS = 50

historial = modelo.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 574s 1s/step - loss: 0.6419 - accuracy: 0.7542 - val_loss: 0.7473 - val_accuracy: 0.7164
# Epoch 2/50
# 390/390 [==============================] - 489s 1s/step - loss: 0.4155 - accuracy: 0.8441 - val_loss: 0.6686 - val_accuracy: 0.7556
# Epoch 3/50
# 390/390 [==============================] - 491s 1s/step - loss: 0.3747 - accuracy: 0.8627 - val_loss: 0.6286 - val_accuracy: 0.7656
# Epoch 4/50
# 390/390 [==============================] - 490s 1s/step - loss: 0.3392 - accuracy: 0.8749 - val_loss: 0.6296 - val_accuracy: 0.7740
# Epoch 5/50
# 390/390 [==============================] - 490s 1s/step - loss: 0.3296 - accuracy: 0.8811 - val_loss: 0.6276 - val_accuracy: 0.7778
# Epoch 6/50
# 390/390 [==============================] - 487s 1s/step - loss: 0.3112 - accuracy: 0.8881 - val_loss: 0.6457 - val_accuracy: 0.7833
# Epoch 7/50
# 390/390 [==============================] - 491s 1s/step - loss: 0.3028 - accuracy: 0.8872 - val_loss: 0.6213 - val_accuracy: 0.7878
# Epoch 8/50
# 390/390 [==============================] - 488s 1s/step - loss: 0.2956 - accuracy: 0.8921 - val_loss: 0.6295 - val_accuracy: 0.7904
# Epoch 9/50
# 390/390 [==============================] - 486s 1s/step - loss: 0.2841 - accuracy: 0.8961 - val_loss: 0.6424 - val_accuracy: 0.7852
# Epoch 10/50
# 390/390 [==============================] - 494s 1s/step - loss: 0.2821 - accuracy: 0.8966 - val_loss: 0.6401 - val_accuracy: 0.7785
# Epoch 11/50
# 390/390 [==============================] - 552s 1s/step - loss: 0.2742 - accuracy: 0.8993 - val_loss: 0.6409 - val_accuracy: 0.7913
# Epoch 12/50
# Epoch 34/50
# 390/390 [==============================] - 483s 1s/step - loss: 0.2315 - accuracy: 0.9137 - val_loss: 0.6871 - val_accuracy: 0.7884
# Epoch 35/50
# 390/390 [==============================] - 484s 1s/step - loss: 0.2315 - accuracy: 0.9174 - val_loss: 0.6248 - val_accuracy: 0.8109
# Epoch 36/50
# 390/390 [==============================] - 485s 1s/step - loss: 0.2340 - accuracy: 0.9118 - val_loss: 0.7029 - val_accuracy: 0.7881
# Epoch 37/50
# 390/390 [==============================] - 485s 1s/step - loss: 0.2269 - accuracy: 0.9186 - val_loss: 0.6529 - val_accuracy: 0.7977
# Epoch 38/50
# 390/390 [==============================] - 487s 1s/step - loss: 0.2235 - accuracy: 0.9165 - val_loss: 0.7302 - val_accuracy: 0.7852
# Epoch 39/50
# 390/390 [==============================] - 486s 1s/step - loss: 0.2364 - accuracy: 0.9135 - val_loss: 0.6706 - val_accuracy: 0.7997
# Epoch 40/50
# 390/390 [==============================] - 483s 1s/step - loss: 0.2398 - accuracy: 0.9122 - val_loss: 0.6873 - val_accuracy: 0.7961
# Epoch 41/50
# 390/390 [==============================] - 482s 1s/step - loss: 0.2291 - accuracy: 0.9141 - val_loss: 0.6789 - val_accuracy: 0.7987
# Epoch 42/50
# 390/390 [==============================] - 482s 1s/step - loss: 0.2378 - accuracy: 0.9138 - val_loss: 0.6868 - val_accuracy: 0.7926
# Epoch 43/50
# 390/390 [==============================] - 486s 1s/step - loss: 0.2267 - accuracy: 0.9134 - val_loss: 0.7171 - val_accuracy: 0.7842
# Epoch 44/50
# 390/390 [==============================] - 488s 1s/step - loss: 0.2299 - accuracy: 0.9144 - val_loss: 0.6815 - val_accuracy: 0.7932
# Epoch 45/50
# 390/390 [==============================] - 483s 1s/step - loss: 0.2252 - accuracy: 0.9135 - val_loss: 0.6685 - val_accuracy: 0.8035
# Epoch 46/50
# 390/390 [==============================] - 485s 1s/step - loss: 0.2278 - accuracy: 0.9162 - val_loss: 0.7046 - val_accuracy: 0.7955
# Epoch 47/50
# 390/390 [==============================] - 486s 1s/step - loss: 0.2272 - accuracy: 0.9169 - val_loss: 0.7376 - val_accuracy: 0.7916
# Epoch 48/50
# 390/390 [==============================] - 486s 1s/step - loss: 0.2284 - accuracy: 0.9182 - val_loss: 0.7143 - val_accuracy: 0.7865
# Epoch 49/50
# 390/390 [==============================] - 484s 1s/step - loss: 0.2331 - accuracy: 0.9142 - val_loss: 0.7276 - val_accuracy: 0.7984
# Epoch 50/50
# 390/390 [==============================] - 483s 1s/step - loss: 0.2300 - accuracy: 0.9153 - val_loss: 0.6895 - val_accuracy: 0.7977

# %%
#Graficas de precisión
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(50)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1, 224, 224, 3)) 
  for x in prediccion[0]:
        x = round(x,5)
        print(str(x))
  return np.argmax(prediccion[0], axis=-1)

def categorizar2(path):
    img = Image.open(path)
    img = np.array(img).astype(float)/255
    img = cv2.resize(img, (224,224))
    prediccion = modelo.predict(img.reshape(-1, 224, 224, 3))
    for x in prediccion[0]:
        x = '{:0.3e}'.format(x)
        print(str(x))
    return np.argmax(prediccion[0], axis=-1)

def mostrarCategoria(nombre):
    print("nombre")
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(image, 'Carton', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow(window_name,image)

# %%
#0 = carton, 1 = vidrio, 2 = metal ,3 = papel , 4 plastico
url = 'https://img2.rtve.es/a/5897383/?h=320'
prediccion = categorizar (url)
print(prediccion)
# Out:
# 0.00044
# 0.0204
# 0.00043
# 0.0
# 0.97874
# 4

# %%
import os


datos = 'capturas'
if not os.path.exists(datos):
    print('Carpeta creada: ',datos)
    os.makedirs(datos)

modelo.save('saved_model/my_model2')
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_model2\assets
# INFO:tensorflow:Assets written to: saved_model/my_model2\assets

# %%
import numpy as np


count = 0 #para contar las capturas
capture = cv2.VideoCapture(0)
while (capture.isOpened()):
    k = cv2.waitKey(1);
    ret, frame = capture.read()
    cv2.imshow('webCam',frame)
    if (k == ord('s')):  #s para cerrar 
        break
    elif (k == ord('c')): #c para sacar captura
        cv2.imwrite(datos+'/objeto_{}.jpg'.format(count),frame)
        print('Imagen guardada:'+'/objeto_{}.jpg'.format(count))
        
        ##captura
        path = datos+'/objeto_{}.jpg'.format(count)
        resultado = categorizar2(path)
        print (resultado)
        image = cv2.imread(path)
        window_name = 'image'
        if resultado == 0:
            print("Carton")
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, 'Carton', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow(window_name,image)
        elif resultado == 1:
            print("Vidrio")
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, 'Vidrio', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow(window_name,image)
        elif resultado == 2:
            print("metal")
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, 'Metal', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow(window_name,image)
        elif resultado == 3:
            print("papel")
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, 'Papel', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow(window_name,image)
        elif resultado == 4:
            print("plastico")
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(image, 'Plastico', (10,450), font, 3, (0, 255, 0), 2, cv2.LINE_AA)
            cv2.imshow(window_name,image)
        count+=1
        
        


capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BRAIAN~1\AppData\Local\Temp/ipykernel_8020/2204349740.py in <module>
#       3
#       4 count = 0 #para contar las capturas
# ----> 5 capture = cv2.VideoCapture(0)
#       6 while (capture.isOpened()):
#       7     k = cv2.waitKey(1);
#
# NameError: name 'cv2' is not defined
